# %%
from config import WINDOW_SIZE
from data.loader import load_price_data, load_carhart_factors
from features.engineering import compute_log_returns, create_lagged_and_split_data, create_lagged_and_split_data_averages
from models.rnn import RNNModel
from models.ffneural_net import FFNModel    
from models.regression import LinRegModel
from evaluation.metrics import compute_sharpe
from strategy.value import value_strategy_predictor

# %%
import numpy as np
import pandas as pd

# %%
# Load data
data_dir = "data/data_full"
price_df = load_price_data(data_dir)

# %%
# Compute returns
log_ret = compute_log_returns(price_df)
carhart = load_carhart_factors(data_dir, log_ret.index)

# stack returns and carhart factors (data has shape (number of trading days, features = number of tickers + 4 carhart factors))
data = np.concatenate((np.array(log_ret),np.array(carhart)),axis=1)

cutoff = np.where(log_ret.index > "2019-08-31")[0][0]  # Find the index where the date is greater than "2019-08-31"

# %% [markdown]
# Train a linear regression to predict future returns based on current returns and Carhart factors

# %%
# data has shape (number of trading days - windowsize, windowsize, features = number of tickers + 4 carhart factors) and second dimension is flattened if model = "linear"
X_train, y_train, X_test, y_test = create_lagged_and_split_data(data = data, windowsize = 1, cutoff = cutoff, model = "linear", carhart=True)

model = LinRegModel()
model.fit(X_train, y_train)
model.evaluate_model(X_test, y_test)
# Out:
# R2: -0.28820511044711594
# MSE: 49.11010462425082

# %% [markdown]
# Train a feedforward NN (with keras) to predict future returns based on current returns and Carhart factors.

# %%
# data has shape (number of trading days - windowsize, windowsize, features = number of tickers + 4 carhart factors) and second dimension is flattened if model = "linear"
X_train, y_train, X_test, y_test = create_lagged_and_split_data(data = data, windowsize = 1, cutoff = cutoff, model = "dnn", carhart=True)

model = FFNModel(X_train, y_train)

model.train_model(validation_data=(X_test,y_test))

model.evaluate_model(X_test, y_test)
# Out:
# c:\Users\Antoine\OneDrive - Universitaet Bern\Documents\macroeconomie\repositories\sp500_predictor\.venv\Lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 7.1430e-04 - loss: 22.4801 - val_accuracy: 0.0028 - val_loss: 39.7862
# Epoch 2/15
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0040 - loss: 19.6071 - val_accuracy: 0.0018 - val_loss: 39.4369
# Epoch 3/15
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0019 - loss: 20.0805 - val_accuracy: 0.0046 - val_loss: 39.3615
# Epoch 4/15
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0028 - loss: 19.9726 - val_accuracy: 0.0018 - val_loss: 39.2981
# Epoch 5/15
# ...

# %% [markdown]
# Train a recurrent NN (with pytorch) to predict future returns based on current returns and Carhart factors.

# %%
# data has shape (number of trading days - windowsize, windowsize, features = number of tickers + 4 carhart factors) and second dimension is flattened if model = "linear"
X_train, y_train, X_test, y_test = create_lagged_and_split_data(data = data, windowsize = 50, cutoff = cutoff, model = "rnn", carhart=True)

# define model specs
model = RNNModel(X_train, y_train, hidden_size=40, num_layers=2) 

# model.modify_loader_otimizer_and_loss(loader, optimizer, loss_fn)

model.train_model(n_epochs=10, x_test=X_test, y_test=y_test)

model.evaluate_model(X_test, y_test)
# Out:
# Epoch 0: train MSE 19.6906, test MSE 40.1520
# Epoch 5: train MSE 18.9611, test MSE 40.2001
# train R2: 0.1355297565460205
# train MSE: 17.168527603149414
# Test R2: -0.03318407014012337
# Test MSE: 41.289283752441406

# %% [markdown]
# Test a trading strategy based on predicted returns. Predict the average return of the next 15 days, long the top 5% stocks and short the bottom 5% stocks. Close positions after 20 days and repeat.

# %%
# stack returns and carhart factors (data has shape (number of trading days, features = number of tickers + 4 carhart factors))
data = pd.merge(log_ret, carhart, left_index=True, right_index=True).dropna()

# reindex price_df to match data index and drop NaN values
price_df = price_df.reindex(data.index).dropna()
print((price_df.index==data.index).all())

n_titles = int(0.05 * len(log_ret.columns))
windowsize = 50

# target is now the average of the next 15 days returns
X_train, y_train, X_test, y_test = create_lagged_and_split_data_averages(data = data, windowsize = 50, cutoff = cutoff)
dates = data.index[windowsize - 1 : len(data) - 15]
print(len(dates) == len(X_train) + len(X_test))
dates = dates[len(X_train) : ]  # Adjust dates to match X_test length
print(len(dates) == len(X_test))
# Out:
# True
# True
# True

# %%
# define model specs
model = RNNModel(X_train, y_train, hidden_size=40, num_layers=2) 

# model.modify_loader_otimizer_and_loss(loader, optimizer, loss_fn)

# model.train_model(n_epochs=10, x_test=X_test, y_test=y_test)
model.train_model(n_epochs=6, x_test=X_test, y_test=y_test)
# Out:
# Epoch 0: train MSE 1.2044, test MSE 2.5945
# Epoch 5: train MSE 0.9237, test MSE 2.6532

# %%
values,trading_dates = value_strategy_predictor(
    X_test, 
    dates, 
    price_df, 
    frequency=20, 
    predictor=model.use_trained_model, 
    n_titles=n_titles,
    plot_=False,
)
sharpe = compute_sharpe(values)
print("Strategy Sharpe Ratio:", sharpe)
# Out:
# Strategy Sharpe Ratio: 0.9625983044318127

# %%
import matplotlib.pyplot as plt
import seaborn as sns

trading_dates = pd.to_datetime(trading_dates) 
sns.set_theme(style="darkgrid")
values = values[1:]  # Adjust values to match trading_dates length

# Wrap in a DataFrame
df = pd.DataFrame({"Date": trading_dates, "Value": values})

plt.figure(figsize=(12, 5))
sns.lineplot(data=df, x="Date", y="Value")
plt.title("Asset Value Over Time")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
sharpe=[]
for shift in range(9):
    dates_shifted = dates[shift:]
    X_test_shifted = X_test[shift: ]
    values,trading_dates = value_strategy_predictor(
        X_test_shifted, 
        dates_shifted, 
        price_df, 
        frequency=20, 
        predictor=model.use_trained_model, 
        n_titles=n_titles
    )
    sharpe.append(compute_sharpe(values))
print('Annualized Sharpe ratio: ',np.mean(sharpe))
# Out:
# Annualized Sharpe ratio:  1.201289941579835
